# %% [markdown]
# ## Using random user API

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x19b08b69090>,
#  <randomuser.RandomUser at 0x19b08b68f50>,
#  <randomuser.RandomUser at 0x19b08a6c3e0>,
#  <randomuser.RandomUser at 0x19b0fa7f360>,
#  <randomuser.RandomUser at 0x19b08a52570>,
#  <randomuser.RandomUser at 0x19b08a156a0>,
#  <randomuser.RandomUser at 0x19b0fad1d00>,
#  <randomuser.RandomUser at 0x19b0fade950>,
#  <randomuser.RandomUser at 0x19b0faded50>,
#  <randomuser.RandomUser at 0x19b0fac3b60>]

# %%
name = r.get_full_name()

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Sofia Welch   sofia.welch@example.com
# Irene Peña   irene.pena@example.com
# Mehdi Walch   mehdi.walch@example.com
# Freja Lundgård   freja.lundgard@example.com
# Ralph Moore   ralph.moore@example.com
# مهدیس حسینی   mhdys.hsyny@example.com
# Arne Sjøvold   arne.sjovold@example.com
# Siglinde Wenger   siglinde.wenger@example.com
# Kimberly Phillips   kimberly.phillips@example.com
# Kasper Wirtanen   kasper.wirtanen@example.com

# %%
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/women/66.jpg
# https://randomuser.me/api/portraits/women/31.jpg
# https://randomuser.me/api/portraits/men/37.jpg
# https://randomuser.me/api/portraits/women/48.jpg
# https://randomuser.me/api/portraits/men/27.jpg
# https://randomuser.me/api/portraits/women/64.jpg
# https://randomuser.me/api/portraits/men/65.jpg
# https://randomuser.me/api/portraits/women/80.jpg
# https://randomuser.me/api/portraits/women/60.jpg
# https://randomuser.me/api/portraits/men/15.jpg

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                 Name  Gender                        City  \
# 0      آنیتا نكو نظر  female                         کرج
# 1       Kurt Vasquez    male                     Killeen
# 2    Charlotte Smith  female                    Maitland
# 3     Joan Dominguez    male                    Alicante
# 4     Hanns Fichtner    male                   Hechingen
# 5      Julian Prieto    male  San Sebastián de Los Reyes
# 6   Rosalie Eickhoff  female                     Heubach
# 7       Silja Winger  female                  Klokkarvik
# 8  Florence Mitchell  female                   Inverness
# 9    Martin Thompson    male                       Perth
#
#                        State                          Email  \
# 0                      گیلان        anyt.nkwnzr@example.com
# 1                      Texas       kurt.vasquez@example.com
# 2                Nova Scotia    charlotte.smith@example.com
# 3                  Cantabria     joan.dominguez@example.com
# 4                   Saarland     hanns.fichtner@example.com
# 5            Castilla y León      julian.prieto@example.com
# 6        Nordrhein-Westfalen   rosalie.eickhoff@example.com
# 7                 Aust-Agder       silja.winger@example.com
# 8  Newfoundland and Labrador  florence.mitchell@example.com
# 9                 Queensland    martin.thompson@example.com
#
#                         DOB                                           Picture
# 0  1992-12-15T16:25:14.195Z   https://randomuser.me/api/portraits/women/6.jpg
# 1  1975-06-16T16:50:30.877Z    https://randomuser.me/api/portraits/men/24.jpg
# 2  1993-03-26T01:54:49.852Z  https://randomuser.me/api/portraits/women/56.jpg
# 3  1974-09-29T00:32:29.074Z    https://randomuser.me/api/portraits/men/47.jpg
# 4  1973-05-22T06:50:10.314Z    https://randomuser.me/api/portraits/men/86.jpg
# 5  1971-07-22T17:28:36.916Z    https://randomuser.me/api/portraits/men/39.jpg
# 6  1979-11-18T19:38:30.768Z  https://randomuser.me/api/portraits/women/35.jpg
# 7  1950-10-03T05:32:49.247Z  https://randomuser.me/api/portraits/women/89.jpg
# 8  1980-02-04T04:50:05.823Z  https://randomuser.me/api/portraits/women/51.jpg
# 9  1964-10-22T02:38:30.371Z    https://randomuser.me/api/portraits/men/33.jpg

# %%
df1 = pd.DataFrame(get_users())

# %%
df1
# Out:
#              Name  Gender            City                      State  \
# 0    Fanny Renken  female  Schrobenhausen                     Bayern
# 1  Dylan Harcourt    male     New Glasgow  Newfoundland and Labrador
# 2    Onur Çağıran    male   Kahramanmaraş                  Kırıkkale
# 3    Emily Wilson  female         Delisle              New Brunswick
# 4     Max Johnson    male       Whanganui          Manawatu-Wanganui
# 5  Gisela Nicolas  female         Samnaun                  Neuchâtel
# 6       Ava Burns  female        Hereford                    Cumbria
# 7  Cecilie Hansen  female         Ansager                Midtjylland
# 8     Jacob Denys    male     Springfield       Prince Edward Island
# 9   Eemil Laurila    male          Pargas       Central Ostrobothnia
#
#                         Email                       DOB  \
# 0    fanny.renken@example.com  1979-01-22T04:16:28.553Z
# 1  dylan.harcourt@example.com  1958-06-23T14:14:54.537Z
# 2    onur.cagiran@example.com  1977-01-02T11:39:43.260Z
# 3    emily.wilson@example.com  1976-03-20T10:44:39.956Z
# 4     max.johnson@example.com  1980-03-17T09:48:47.585Z
# 5  gisela.nicolas@example.com  1964-08-13T15:21:00.673Z
# 6       ava.burns@example.com  1962-06-16T18:22:02.229Z
# 7  cecilie.hansen@example.com  1971-08-25T19:08:53.949Z
# 8     jacob.denys@example.com  1951-09-03T05:26:43.167Z
# 9   eemil.laurila@example.com  1946-10-05T10:22:02.550Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/77.jpg
# 1    https://randomuser.me/api/portraits/men/24.jpg
# 2    https://randomuser.me/api/portraits/men/69.jpg
# 3   https://randomuser.me/api/portraits/women/4.jpg
# 4    https://randomuser.me/api/portraits/men/12.jpg
# 5  https://randomuser.me/api/portraits/women/62.jpg
# 6  https://randomuser.me/api/portraits/women/85.jpg
# 7  https://randomuser.me/api/portraits/women/48.jpg
# 8    https://randomuser.me/api/portraits/men/39.jpg
# 9    https://randomuser.me/api/portraits/men/90.jpg
